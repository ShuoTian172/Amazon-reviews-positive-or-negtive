# %%
import io
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import string
import pandas as pd

# %%
## pos.txt filtered without stop words

# %%
# Out:
# ['My daughter wanted this book and the price on Amazon was the best.',
#  'She has already tried one recipe a day after receiving the book.',
#  'I bought this zoku quick pop for my daughterr with her zoku quick maker.',
#  'She loves it and have fun to make her own ice cream.',
#  'I was hoping there were more where those came from.']

# %%
# load data
file = open("test.txt", 'rt')
text = file.read()
file.close()

# %%
# split into sentences
from nltk import sent_tokenize
sentences = sent_tokenize(text)
sentences
# Out:
# ['My daughter wanted this book and the price on Amazon was the best.',
#  'She has already tried one recipe a day after receiving the book.',
#  'I bought this zoku quick pop for my daughterr with her zoku quick maker.',
#  'She loves it and have fun to make her own ice cream.',
#  'I was hoping there were more where those came from.',
#  'This book emphasizes very sweet dessert pops, however.',
#  'There are 41 recipes in total, only 13 of which are fruit pops.',
#  'There is a "Fresh and Fruity" chapter, followed by three chapters of dessert pops entitled "I Scream for Quick Pops!',
#  '", "Bake Shop", and  "Coco Loco".']

# %%
# Creating a dataframe object from list
sentences = pd.DataFrame(sentences) 

# split into words
tokens = word_tokenize(text)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word

# stripped = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）]+", "",stripped)
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]

#write in files
for r in words: 
    if not r in stop_words: 
        appendFile = open('filtered_pos.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()

# %%
## neg.txt filtered without stop words

# %%
# load data
file = open("neg.txt", 'rt')
text = file.read()
file.close()

# split into words
tokens = word_tokenize(text)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]

#write in files
for r in words: 
    if not r in stop_words: 
        appendFile = open('filtered_neg.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()

# %%
## pos.txt filtered with stop words

# %%
# load data
file = open("pos.txt", 'rt')
text = file.read()
file.close()

# split into words
tokens = word_tokenize(text)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

#write in files
for r in words: 
    if not r in stop_words: 
        appendFile = open('filtered_pos_w_stop.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()

# %%
## neg.txt filtered with stop words

# %%
# load data
file = open("neg.txt", 'rt')
text = file.read()
file.close()

# split into words
tokens = word_tokenize(text)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

#write in files
for r in words: 
    if not r in stop_words: 
        appendFile = open('filtered_neg_w_stop.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()

# %%
f_pos_file= open('filtered_pos.txt')
f_pos_text = f_pos_file.read()
f_pos_file.close()

# %%
f_pos_text.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-40c4f723e41c> in <module>()
# ----> 1 f_pos_text.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
import numpy as np
f_pos_train, f_pos_validate, f_pos_test = np.split(f_pos_text.sample(frac=1), [int(.8*len(f_pos_text)), int(.9*len(f_pos_text))])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-96c6755a4121> in <module>()
#       1 import numpy as np
# ----> 2 f_pos_train, f_pos_validate, f_pos_test = np.split(f_pos_text(frac=1), [int(.8*len(f_pos_text)), int(.9*len(f_pos_text))])
#
# TypeError: 'str' object is not callable

# %%
import re
# load data
file = open("test.txt", 'rt')
text = file.read()
file.close()

# split into sentences
from nltk import sent_tokenize
sentences = sent_tokenize(text)

sentence=[]

for i in sentences:
    sentence.append(i)


# split into words
tokens = word_tokenize(sentence)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word


table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print (words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-a6f60e991cbd> in <module>()
#      16
#      17 # split into words
# ---> 18 tokens = word_tokenize(sentence)
#      19
#      20 # convert to lower case
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
# ...

# %%
np.savetxt("train.csv", train_list, delimiter=",", fmt='%s')

# %%
# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word

# stripped = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）]+", "",stripped)
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]

#write in files
for r in words: 
    if not r in stop_words: 
        appendFile = open('filtered_test.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()

# %%
import pandas as pd

# load data
file = open("test.txt", 'rt')
text = file.read()
file.close()
sentences = sent_tokenize(text)

test = pd.DataFrame(sentences)
test.columns = ["sentence"]
test
# Out:
#                                              sentence
# 0   She has already tried one recipe a day after r...
# 1   I bought this zoku quick pop for my daughterr ...
# 2   She loves it and have fun to make her own ice ...
# 3   I was hoping there were more where those came ...
# 4   This book emphasizes very sweet dessert pops, ...
# 5   There are 41 recipes in total, only 13 of whic...
# 6   There is a "Fresh and Fruity" chapter, followe...
# 7                   ", "Bake Shop", and  "Coco Loco".
# 8   As you might guess from the last one, there ar...
# 9   There is more detailed information about ingre...
# 10  The pages about core pops are especially helpf...
# 11  Many, including the recipe for a vanilla base,...
# 12  On the bright side, many of these recipes may ...
# 13  There are flavors like "Cookie Dough", "That's...
# 14  Most of the fruit recipes are gimmicky and con...
# 15  The recipe for Lemonade pops contains orange j...

# %%
np.savetxt("train.csv", test.sentence, delimiter=",", fmt='%s')

# %%
test['sentence'] = test['sentence'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# Out:
# 0    she has already tried one recipe a day after r...
# 1    i bought this zoku quick pop for my daughterr ...
# 2    she loves it and have fun to make her own ice ...
# 3    i was hoping there were more where those came ...
# 4    this book emphasizes very sweet dessert pops, ...
# Name: sentence, dtype: object

# %%
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in test['sentence']]
# Out:
# ['she has already tried one recipe a day after receiving the book',
#  'i bought this zoku quick pop for my daughterr with her zoku quick maker',
#  'she loves it and have fun to make her own ice cream',
#  'i was hoping there were more where those came from',
#  'this book emphasizes very sweet dessert pops however',
#  'there are 41 recipes in total only 13 of which are fruit pops',
#  'there is a fresh and fruity chapter followed by three chapters of dessert pops entitled i scream for quick pops',
#  ' bake shop and coco loco',
#  'as you might guess from the last one there are 15 pop recipes that contain chocolatechapters on tips and techniques are useful',
#  'there is more detailed information about ingredients that dont freeze well in the zoku than is found in the instruction manual',
#  'the pages about core pops are especially helpful as they include recipes for pink purple and orange outer layers for brightlycolored core pops',
# ...

# %%
# remove remaining tokens that are not alphabetic
words_list = []
words =[]
for i in stripped:
    for word in i:
        if word.isalpha():
            words.append(word)
    words_list.append(words)
            
words_list
# Out:
# [[],
#  ['s',
#   'h',
#   'e',
#   'h',
#   'a',
#   's',
#   'a',
#   'l',
#   'r',
#   'e',
#   'a',
#   'd',
#   'y',
#   't',
#   'r',
#   'i',
#   'e',
#   'd',
#   'o',
#   'n',
#   'e',
#   'r',
#   'e',
#   'c',
#   'i',
#   'p',
#   'e',
#   'a',
#   'd',
#   'a',
#   'y',
#   'a',
#   'f',
#   't',
#   'e',
#   'r',
#   'r',
#   'e',
#   'c',
#   'e',
#   'i',
#   'v',
#   'i',
#   'n',
#   'g',
#   't',
#   'h',
#   'e',
#   'b',
#   'o',
#   'o',
#   'k',
#   'i',
#   'b',
#   'o',
#   'u',
#   'g',
#   'h',
#   't',
#   't',
#   'h',
#   'i',
#   's',
#   'z',
#   'o',
#   'k',
#   'u',
#   'q',
#   'u',
#   'i',
#   'c',
#   'k',
#   'p',
#   'o',
#   'p',
#   'f',
#   'o',
#   'r',
#   'm',
#   'y',
#   'd',
#   'a',
#   'u',
#   'g',
#   'h',
#   't',
#   'e',
#   'r',
#   'r',
#   'w',
#   'i',
#   't',
#   'h',
#   'h',
#   'e',
#   'r',
#   'z',
#   'o',
#   'k',
#   'u',
#   'q',
#   'u',
#   'i',
#   'c',
#   'k',
#   'm',
#   'a',
#   'k',
#   'e',
#   'r',
# ...

# %%
# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print (words)

# %%
# load data
file = open("test.txt", 'rt')
text = file.read()
file.close()

# split into sentences
sentences = sent_tokenize(text)

# split into words
tokens = word_tokenize(sentence)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word


table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print (words)

# %%
with open("test.txt", "r") as ins:
    array = []
    for line in ins:
        array.append(line)

# %%
with open("test.txt", "r") as f:
    content = f.read().splitlines()

# %%
content
# Out:
# ['She has already tried one recipe a day after receiving the book.',
#  'I bought this zoku quick pop for my daughterr with her zoku quick maker.',
#  'She loves it and have fun to make her own ice cream.',
#  'I was hoping there were more where those came from.',
#  'This book emphasizes very sweet dessert pops, however.',
#  'There are 41 recipes in total, only 13 of which are fruit pops.',
#  'There is a "Fresh and Fruity" chapter, followed by three chapters of dessert pops entitled "I Scream for Quick Pops!", "Bake Shop", and  "Coco Loco".',
#  'As you might guess from the last one, there are 15 pop recipes that contain chocolate.Chapters on "Tips" and "Techniques" are useful.',
#  "There is more detailed information about ingredients that don't freeze well in the Zoku than is found in the instruction manual.",
#  'The pages about core pops are especially helpful, as they include recipes for pink, purple, and orange outer layers for brightly-colored core pops.',
# ...

# %%
np.savetxt("train.csv", train_list, delimiter=",", fmt='%s')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-47b2743daf87> in <module>()
# ----> 1 np.savetxt("train.csv", train_list, delimiter=",", fmt='%s')
#       2 data = pd.read_csv("train.csv")
#
# NameError: name 'train_list' is not defined

# %%
data = pd.read_csv("train.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-113-8d21486d662e> in <module>()
# ----> 1 data = pd.read_csv("train.csv")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
import pandas as pd

# load data
file = open("test.txt", 'rt')
text = file.read()
file.close()
sentences = sent_tokenize(text)
len(sentences)
# Out:
# 16

# %%
n = len(sentences)
a = [0] * len(sentences)
for i in range(len(sentences)):
    a[i] = [sentences[i]]

# %%
a
# Out:
# [['She has already tried one recipe a day after receiving the book.'],
#  ['I bought this zoku quick pop for my daughterr with her zoku quick maker.'],
#  ['She loves it and have fun to make her own ice cream.'],
#  ['I was hoping there were more where those came from.'],
#  ['This book emphasizes very sweet dessert pops, however.'],
#  ['There are 41 recipes in total, only 13 of which are fruit pops.'],
#  ['There is a "Fresh and Fruity" chapter, followed by three chapters of dessert pops entitled "I Scream for Quick Pops!'],
#  ['", "Bake Shop", and  "Coco Loco".'],
#  ['As you might guess from the last one, there are 15 pop recipes that contain chocolate.Chapters on "Tips" and "Techniques" are useful.'],
#  ["There is more detailed information about ingredients that don't freeze well in the Zoku than is found in the instruction manual."],
# ...

# %%
n = len(sentences)
tokens = [0] * len(sentences)
for i in range(len(sentences)):
    tokens[i] = [word_tokenize(a[i])]

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word

table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print (words)

# %%
n = len(sentences)
tokens = [0] * n
for i in range(len(sentences)):
    tokens = word_tokenize(str(a[i]))

# %%
tokens[:20]
# Out:
# ['[',
#  "'The",
#  'recipe',
#  'for',
#  'Lemonade',
#  'pops',
#  'contains',
#  'orange',
#  'juice',
#  ',',
#  'which',
#  'is',
#  'fine',
#  ',',
#  'but',
#  'the',
#  'addition',
#  'of',
#  'vanilla',
#  'extract']

# %%
# split into words
for i in a 
tokens = word_tokenize(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-c7754d649ef1> in <module>()
#       1 # split into words
# ----> 2 tokens = word_tokenize(a)
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# ...

# %%
b= pd.DataFrame(a)

# %%
b.head()
# Out:
#                                                    0
# 0  She has already tried one recipe a day after r...
# 1  I bought this zoku quick pop for my daughterr ...
# 2  She loves it and have fun to make her own ice ...
# 3  I was hoping there were more where those came ...
# 4  This book emphasizes very sweet dessert pops, ...

# %%
b.to_csv('example.csv')

# %%
import numpy as np
train, validate, test = np.split(b.sample(frac=1), [int(.8*len(b)), int(.9*len(b))])

# %%
train.to_csv('example-train.csv')

# %%
validate
# Out:
#                                                     0
# 2   She loves it and have fun to make her own ice ...
# 11  Many, including the recipe for a vanilla base,...

# %%
test
# Out:
#                                                     0
# 7                   ", "Bake Shop", and  "Coco Loco".
# 15  The recipe for Lemonade pops contains orange j...

# %%
# Read in the raw text
rawData = open ("pos.txt").read()
#print the raw data
rawData[:250]
# Out:
# 'My daughter wanted this book and the price on Amazon was the best.\nShe has already tried one recipe a day after receiving the book.\nI bought this zoku quick pop for my daughterr with her zoku quick maker.\nShe loves it and have fun to make her own ice'

# %%
import pandas as pd
#Reading Tab seperated value
data = pd.read_csv('pos.txt', sep='\n', names = ['body_text'], header=None)

#Print first 5 data
data.head()
# Out:
#                                            body_text
# 0  My daughter wanted this book and the price on ...
# 1  She has already tried one recipe a day after r...
# 2  I bought this zoku quick pop for my daughterr ...
# 3  She loves it and have fun to make her own ice ...
# 4  I was hoping there were more where those came ...

# %%
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
## Remove punctuation
import string
string.punctuation#Function to remove Punctuation
def remove_punc(text):
    text_nopunc = "".join([char for char in text if char not in string.punctuation])
    return text_nopunc
data['body_text_clean'] = data['body_text'].apply(lambda x: remove_punc(x))

data.head()
# Out:
#                                            body_text  \
# 0  My daughter wanted this book and the price on ...
# 1  She has already tried one recipe a day after r...
# 2  I bought this zoku quick pop for my daughterr ...
# 3  She loves it and have fun to make her own ice ...
# 4  I was hoping there were more where those came ...
#
#                                      body_text_clean
# 0  My daughter wanted this book and the price on ...
# 1  She has already tried one recipe a day after r...
# 2  I bought this zoku quick pop for my daughterr ...
# 3  She loves it and have fun to make her own ice ...
# 4  I was hoping there were more where those came ...

# %%
import re

# Function to Tokenize words
def tokenize(text):
    tokens = re.split('\W+', text) #W+ means that either a word character (A-Za-z0-9_) or a dash (-) can go there.
    return tokens

data['body_text_tokenized'] = data['body_text_clean'].apply(lambda x: tokenize(x.lower())) 
#We convert to lower as Python is case-sensitive. 

data.head()
# Out:
#                                            body_text  \
# 0  My daughter wanted this book and the price on ...
# 1  She has already tried one recipe a day after r...
# 2  I bought this zoku quick pop for my daughterr ...
# 3  She loves it and have fun to make her own ice ...
# 4  I was hoping there were more where those came ...
#
#                                      body_text_clean  \
# 0  My daughter wanted this book and the price on ...
# 1  She has already tried one recipe a day after r...
# 2  I bought this zoku quick pop for my daughterr ...
# 3  She loves it and have fun to make her own ice ...
# 4  I was hoping there were more where those came ...
#
#                                  body_text_tokenized
# 0  [my, daughter, wanted, this, book, and, the, p...
# 1  [she, has, already, tried, one, recipe, a, day...
# 2  [i, bought, this, zoku, quick, pop, for, my, d...
# 3  [she, loves, it, and, have, fun, to, make, her...
# 4  [i, was, hoping, there, were, more, where, tho...

# %%
import nltk

stopword = nltk.corpus.stopwords.words('english')# All English Stopwords

# Function to remove Stopwords
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]# To remove all stopwords
    return text

data['body_text_nostop'] = data['body_text_tokenized'].apply(lambda x: remove_stopwords(x))

data.head()
# Out:
#                                            body_text  \
# 0  My daughter wanted this book and the price on ...
# 1  She has already tried one recipe a day after r...
# 2  I bought this zoku quick pop for my daughterr ...
# 3  She loves it and have fun to make her own ice ...
# 4  I was hoping there were more where those came ...
#
#                                      body_text_clean  \
# 0  My daughter wanted this book and the price on ...
# 1  She has already tried one recipe a day after r...
# 2  I bought this zoku quick pop for my daughterr ...
# 3  She loves it and have fun to make her own ice ...
# 4  I was hoping there were more where those came ...
#
#                                  body_text_tokenized  \
# 0  [my, daughter, wanted, this, book, and, the, p...
# 1  [she, has, already, tried, one, recipe, a, day...
# 2  [i, bought, this, zoku, quick, pop, for, my, d...
# 3  [she, loves, it, and, have, fun, to, make, her...
# ...

# %%
import re
# load data
file = open("test.txt", 'rt')
text = file.read()
file.close()

# split into sentences
from nltk import sent_tokenize
sentences = sent_tokenize(text)

sentence=[]

for i in sentences:
    sentence.append(i)


# split into words
tokens = word_tokenize(sentence)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print (words)

# %%
import numpy as np

# %%
from nltk import sent_tokenize
import io
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import string
import pandas as pd
import re
import codecs
import sys
import nltk
import numpy as np
from sklearn.model_selection import train_test_split
nltk.download('stopwords')
from nltk.corpus import stopwords
stopword = set(stopwords.words('english'))



def fileread(filepath): 
    f=open(filepath)
    raw=f.read().split('\n')
    return raw


# Function to remove Stopwords
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]# To remove all stopwords
    return text


# Function to Tokenize words
def tokenize(text):
    tokens = re.split('\W+', text) #W+ means that either a word character (A-Za-z0-9_) or a dash (-) can go there.
    return tokens


## Remove punctuation

string.punctuation#Function to remove Punctuation
def remove_punc(text):
    text_nopunc = "".join([char for char in text if char not in string.punctuation])
    return text_nopunc




if __name__ == "__main__":
    input_path = '/Users/shuotian/NLP_Assignment/pos.txt'
    pos=fileread(input_path)
    i=0
    pos_stop=[]
    pos_no_stop=[]
    for i in range (0,len(pos)):
        p=tokenize(remove_punc(pos[i]))
        pos_no_stop.append(p)
        p=remove_stopwords(p)
        pos_stop.append(p)
        i=i+1
    pos_train, pos_validate, pos_test = np.split(pos_stop.sample(frac=1), [int(.8*len(pos_stop)), int(.9*len(pos_stop))])    
    np.savetxt("pos_train.csv", pos_train, delimiter=",",fmt='%s')
    np.savetxt("pos_val.csv", pos_validate, delimiter=",", fmt='%s')
    np.savetxt("pos_test.csv", pos_test, delimiter=",", fmt='%s')
    pos_no_stop_train, pos_no_stop_validate, pos_no_stop_test = np.split(pos_no_stop.sample(frac=1), [int(.8*len(pos_no_stop)), int(.9*len(pos_no_stop))
    np.savetxt("pos_train_no_stopword.csv", pos_no_stop_train, delimiter=",", fmt='%s')
    np.savetxt("pos_val_no_stopword.csv", pos_no_stop_validate,delimiter=",", fmt='%s')
    np.savetxt("pos_test_no_stopword.csv", pos_no_stop_test, delimiter=",", fmt='%s')
    print(pos_stop[0:9])
# Out:
#   File "<ipython-input-167-14f065f345fd>", line 64
#     np.savetxt("pos_train_no_stopword.csv", pos_no_stop_train, delimiter=",", fmt='%s')
#      ^
# SyntaxError: invalid syntax

# %%
f_pos_train, f_pos_validate, f_pos_test = np.split(f_pos_text.sample(frac=1), [int(.8*len(f_pos_text)), int(.9*len(f_pos_text))])
